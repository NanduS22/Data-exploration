# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df=pd.read_csv("/home/student/Downloads/Annual_Surface_Temperature_Change.csv")
df
# Out:
#      ObjectId                              Country ISO2 ISO3  \
# 0           1         Afghanistan, Islamic Rep. of   AF  AFG
# 1           2                              Albania   AL  ALB
# 2           3                              Algeria   DZ  DZA
# 3           4                       American Samoa   AS  ASM
# 4           5             Andorra, Principality of   AD  AND
# 5           6                               Angola   AO  AGO
# 6           7                             Anguilla   AI  AIA
# 7           8                  Antigua and Barbuda   AG  ATG
# 8           9                            Argentina   AR  ARG
# 9          10                     Armenia, Rep. of   AM  ARM
# 10         11    Aruba, Kingdom of the Netherlands   AW  ABW
# 11         12                            Australia   AU  AUS
# 12         13                              Austria   AT  AUT
# 13         14                  Azerbaijan, Rep. of   AZ  AZE
# ...

# %%
df.columns
# Out:
# Index(['ObjectId', 'Country', 'ISO2', 'ISO3', 'Indicator', 'Unit', 'Source',
#        'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor', 'F1961', 'F1962',
#        'F1963', 'F1964', 'F1965', 'F1966', 'F1967', 'F1968', 'F1969', 'F1970',
#        'F1971', 'F1972', 'F1973', 'F1974', 'F1975', 'F1976', 'F1977', 'F1978',
#        'F1979', 'F1980', 'F1981', 'F1982', 'F1983', 'F1984', 'F1985', 'F1986',
#        'F1987', 'F1988', 'F1989', 'F1990', 'F1991', 'F1992', 'F1993', 'F1994',
#        'F1995', 'F1996', 'F1997', 'F1998', 'F1999', 'F2000', 'F2001', 'F2002',
#        'F2003', 'F2004', 'F2005', 'F2006', 'F2007', 'F2008', 'F2009', 'F2010',
#        'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018',
#        'F2019', 'F2020', 'F2021'],
#       dtype='object')

# %%
climate_subset=df[['ObjectId', 'Country', 'ISO2', 'ISO3', 'Indicator', 'Unit', 'Source',
       'CTS_Code', 'CTS_Name', 'CTS_Full_Descriptor','F2001', 'F2002',
       'F2003', 'F2004', 'F2005', 'F2006', 'F2007', 'F2008', 'F2009', 'F2010',
       'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016', 'F2017', 'F2018',
       'F2019', 'F2020', 'F2021']]
climate_subset
# Out:
#      ObjectId                              Country ISO2 ISO3  \
# 0           1         Afghanistan, Islamic Rep. of   AF  AFG
# 1           2                              Albania   AL  ALB
# 2           3                              Algeria   DZ  DZA
# 3           4                       American Samoa   AS  ASM
# 4           5             Andorra, Principality of   AD  AND
# 5           6                               Angola   AO  AGO
# 6           7                             Anguilla   AI  AIA
# 7           8                  Antigua and Barbuda   AG  ATG
# 8           9                            Argentina   AR  ARG
# 9          10                     Armenia, Rep. of   AM  ARM
# 10         11    Aruba, Kingdom of the Netherlands   AW  ABW
# 11         12                            Australia   AU  AUS
# 12         13                              Austria   AT  AUT
# 13         14                  Azerbaijan, Rep. of   AZ  AZE
# ...

# %%
climate_subset.isna().sum()
# Out:
# ObjectId                0
# Country                 0
# ISO2                    2
# ISO3                    0
# Indicator               0
# Unit                    0
# Source                  0
# CTS_Code                0
# CTS_Name                0
# CTS_Full_Descriptor     0
# F2001                  18
# F2002                  15
# F2003                  12
# F2004                  13
# F2005                  14
# F2006                  11
# F2007                  10
# F2008                  14
# F2009                  13
# F2010                  12
# F2011                  10
# F2012                  13
# F2013                  11
# F2014                  11
# F2015                  11
# F2016                  12
# F2017                  13
# F2018                  11
# F2019                  12
# F2020                  13
# F2021                  13
# dtype: int64

# %%
x=climate_subset[climate_subset['F2001'].isna()]
x
# Out:
#      ObjectId                      Country ISO2 ISO3  \
# 7           8          Antigua and Barbuda   AG  ATG
# 36         37               Cayman Islands   KY  CYM
# 65         66  Falkland Islands (Malvinas)   FK  FLK
# 134       135                   Montenegro   ME  MNE
# 135       136                   Montserrat   MS  MSR
# 140       141               Nauru, Rep. of   NR  NRU
# 148       149                         Niue   NU  NIU
# 154       155               Palau, Rep. of   PW  PLW
# 175       176              Serbia, Rep. of   RS  SRB
# 178       179                    Singapore   SG  SGP
# 181       182              Solomon Islands   SB  SLB
# 184       185         South Sudan, Rep. of   SS  SSD
# 187       188          St. Kitts and Nevis   KN  KNA
# 190       191                        Sudan   SD  SDN
# 199       200    Timor-Leste, Dem. Rep. of   TL  TLS
# 201       202                      Tokelau   TK  TKL
# 207       208     Turks and Caicos Islands   TC  TCA
# ...

# %%
x.count()
# Out:
# ObjectId               18
# Country                18
# ISO2                   18
# ISO3                   18
# Indicator              18
# Unit                   18
# Source                 18
# CTS_Code               18
# CTS_Name               18
# CTS_Full_Descriptor    18
# F2001                   0
# F2002                   3
# F2003                   6
# F2004                   6
# F2005                   7
# F2006                   9
# F2007                   9
# F2008                   7
# F2009                   9
# F2010                   9
# F2011                  11
# F2012                  10
# F2013                  11
# F2014                  11
# F2015                  11
# F2016                  11
# F2017                  11
# F2018                  11
# F2019                  10
# F2020                  11
# F2021                  11
# dtype: int64

# %%
climate_subset.describe()
# Out:
#          ObjectId       F2001       F2002       F2003       F2004       F2005  \
# count  227.000000  209.000000  212.000000  215.000000  214.000000  213.000000
# mean   114.013216    0.862426    0.929726    0.845009    0.773748    0.847423
# std     65.696573    0.454363    0.371618    0.426797    0.355358    0.375802
# min      1.000000    0.030000    0.032000   -0.268000   -0.516000   -0.287000
# 25%     57.500000    0.515000    0.693750    0.615000    0.533750    0.611000
# 50%    114.000000    0.728000    0.845000    0.871000    0.737500    0.844000
# 75%    170.500000    1.259000    1.131000    1.077500    0.962500    1.090000
# max    230.000000    1.977000    2.252000    2.317000    2.156000    2.195000
#
#             F2006       F2007       F2008       F2009       F2010       F2011  \
# count  216.000000  217.000000  213.000000  214.000000  215.000000  217.000000
# mean     0.856264    1.011590    0.796239    0.902065    1.087791    0.803995
# ...

# %%
climate_subset.dtypes
# Out:
# ObjectId                 int64
# Country                 object
# ISO2                    object
# ISO3                    object
# Indicator               object
# Unit                    object
# Source                  object
# CTS_Code                object
# CTS_Name                object
# CTS_Full_Descriptor     object
# F2001                  float64
# F2002                  float64
# F2003                  float64
# F2004                  float64
# F2005                  float64
# F2006                  float64
# F2007                  float64
# F2008                  float64
# F2009                  float64
# F2010                  float64
# F2011                  float64
# F2012                  float64
# F2013                  float64
# F2014                  float64
# F2015                  float64
# F2016                  float64
# F2017                  float64
# F2018                  float64
# F2019                  float64
# F2020                  float64
# ...

# %%
climate_subset.hist(bins=6,figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'ObjectId'}>,
#         <AxesSubplot:title={'center':'F2001'}>,
#         <AxesSubplot:title={'center':'F2002'}>,
#         <AxesSubplot:title={'center':'F2003'}>,
#         <AxesSubplot:title={'center':'F2004'}>],
#        [<AxesSubplot:title={'center':'F2005'}>,
#         <AxesSubplot:title={'center':'F2006'}>,
#         <AxesSubplot:title={'center':'F2007'}>,
#         <AxesSubplot:title={'center':'F2008'}>,
#         <AxesSubplot:title={'center':'F2009'}>],
#        [<AxesSubplot:title={'center':'F2010'}>,
#         <AxesSubplot:title={'center':'F2011'}>,
#         <AxesSubplot:title={'center':'F2012'}>,
#         <AxesSubplot:title={'center':'F2013'}>,
#         <AxesSubplot:title={'center':'F2014'}>],
#        [<AxesSubplot:title={'center':'F2015'}>,
#         <AxesSubplot:title={'center':'F2016'}>,
#         <AxesSubplot:title={'center':'F2017'}>,
#         <AxesSubplot:title={'center':'F2018'}>,
# ...

# %%
x1=climate_subset[climate_subset['F2001']<1]
x2=climate_subset[climate_subset['F2002']<1]
x3=climate_subset[climate_subset['F2003']<1]
x4=climate_subset[climate_subset['F2004']<1]
print(x1)
print(x2)
print(x3)
print(x4)
# Out:
#      ObjectId                              Country ISO2 ISO3  \
# 3           4                       American Samoa   AS  ASM
# 5           6                               Angola   AO  AGO
# 6           7                             Anguilla   AI  AIA
# 8           9                            Argentina   AR  ARG
# 10         11    Aruba, Kingdom of the Netherlands   AW  ABW
# 11         12                            Australia   AU  AUS
# 14         15                         Bahamas, The   BS  BHS
# 16         17                           Bangladesh   BD  BGD
# 17         18                             Barbados   BB  BRB
# 20         21                               Belize   BZ  BLZ
# 21         22                                Benin   BJ  BEN
# 22         23                               Bhutan   BT  BTN
# 23         24                              Bolivia   BO  BOL
# 25         26                             Botswana   BW  BWA
# ...

# %%
x1[['ObjectId','F2001']].plot(kind='scatter', x='ObjectId', y='F2001', figsize=(20,10))
x2[['ObjectId','F2002']].plot(kind='scatter', x='ObjectId', y='F2002', figsize=(20,10))
x3[['ObjectId','F2003']].plot(kind='scatter', x='ObjectId', y='F2003', figsize=(20,10))
x4[['ObjectId','F2004']].plot(kind='scatter', x='ObjectId', y='F2004', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='ObjectId', ylabel='F2004'>
